# %% [markdown]
# __In this notebook, we are going to build a time series model to predict the future price of gold, which can be very useful for traders. For this purpose, we use the historical gold price data for 10 years (from 2013 to 2023).__

# %% [markdown]
# ### Let's get started:

# %% [markdown]
# # Step 1: Importing Libraries

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\arian\appdata\local\programs\python\python39\lib\site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\arian\appdata\local\programs\python\python39\lib\site-packages (from plotly) (1.25.2)
# Requirement already satisfied: packaging in c:\users\arian\appdata\local\programs\python\python39\lib\site-packages (from plotly) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\arian\appdata\local\programs\python\python39\lib\site-packages (from packaging->plotly) (2.4.7)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arian\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arian\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arian\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM
# Out:
# c:\users\arian\appdata\local\programs\python\python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Step 2: Reading Dataset

# %%
df = pd.read_csv('Gold_Price_2013-2023.csv')

# %% [markdown]
# # Step 3: Dataset Overview

# %%
df
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1     12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2     12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3     12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4     12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%
# ...          ...       ...       ...       ...       ...      ...      ...
# 2578  01/08/2013  1,663.20  1,651.50  1,662.60  1,648.80    0.13K    0.97%
# 2579  01/07/2013  1,647.20  1,657.30  1,663.80  1,645.30    0.09K   -0.16%
# 2580  01/04/2013  1,649.90  1,664.40  1,664.40  1,630.00    0.31K   -1.53%
# 2581  01/03/2013  1,675.60  1,688.00  1,689.30  1,664.30    0.19K   -0.85%
# 2582  01/02/2013  1,689.90  1,675.80  1,695.00  1,672.10    0.06K    0.78%
#
# [2583 rows x 7 columns]

# %% [markdown]
# __As you can see, the data set includes daily gold price information including daily Open, High and Low prices and the final price of each day (Price) along with the volume of transactions and price changes in each day.__

# %% [markdown]
# __Dataset Basic Information:__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %% [markdown]
# __All variables are stored as object.__

# %% [markdown]
# # Step 4: Data Preparation

# %% [markdown]
# ## Step 4.1: Feature Subset Selection
# __Since we will not use Vol. and Change % features to predict Price, we will drop these two features:__

# %%
df.drop(['Vol.', 'Change %'], axis=1, inplace=True)

# %% [markdown]
# ## Step 4.2: Transforming Data

# %% [markdown]
# __Date feature is stored as object in the data frame. To increase the speed of calculations, we convert it's data type to datetime and then sort this feature in ascending order:__

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# __The " , " sign is redundant in the dataset. First, we remove it from the entire dataset and then change the data type of the numerical variables to float:__

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %% [markdown]
# __Result:__

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %% [markdown]
# ## Step 4.3: Checking Duplicates
# __There are no duplicate samples in Date feature:__

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step 4.4: Checking Missing Values
# __There are no missing values in the dataset:__

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Step 5: Visualizing Gold Price History Data
#
# __Interactive Gold Price Chart:__

# %%
# fig = px.line(y=df.Price, x=df.Date)
# fig.update_traces(line_color='black') 
# fig.update_layout(xaxis_title="Date", 
#                   yaxis_title="Scaled Price",
#                   title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
#                   plot_bgcolor='rgba(205,223,0,0.8)')

# %% [markdown]
# # Step 6: Splitting Data to Training & Test Sets
# __Since we cannot train on future data in time series data, we should not divide the time series data randomly. In time series splitting, testing set is always later than training set. We consider the last year for testing and everything else for training:__

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %% [markdown]
# __Plot Gold Price Training and Test Sets:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'white'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # Step 7: Data Scaling
# __Since we aim to predict Price only based on its historical data, we scale Price using MinMaxScaler to avoid intensive computations:__

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %% [markdown]
# # Step 8: Restructure Data & Create Sliding Window
# __The use of prior time steps to predict the next time step is called sliding window. In this way, time series data can be expressed as supervised learning. We can do this by using previous time steps as input variables and use the next time step as the output variable. The number of previous time steps is called the window width. Here we set window width to 60. Therefore, X_train and X_test will be nested lists containing lists of 60 time-stamp prices. y_train and y_test are also lists of gold prices containing the next day's gold price corresponds to each list in X_train and X_test respectively:__

# %%
window_size = 60

# %% [markdown]
# __Training Set:__

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %% [markdown]
# __Test Set:__

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %% [markdown]
# # Step 9: Converting Data to Numpy Arrays
#
# __Now X_train and X_test are nested lists (two-dimensional lists) and y_train is a one-dimensional list. We need to convert them to numpy arrays with a higher dimension, which is the data format accepted by TensorFlow when training the neural network:__

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %% [markdown]
# # Step 10: Creating an LSTM Network
# __We build an LSTM network, which is a type of Recurrent Neural Networks designed to solve vanishing gradient problem:__

# %% [markdown]
# __Model Definition:__

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)  
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()
    
    return model

# %% [markdown]
# __Model Training:__

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 1)]           0
#
#  lstm (LSTM)                 (None, 60, 64)            16896
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 85,057
# Trainable params: 85,057
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 64/64 [==============================] - 9s 70ms/step - loss: 0.0379 - val_loss: 0.0653
# Epoch 2/150
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0104 - val_loss: 0.0261
# Epoch 3/150
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0063 - val_loss: 0.0107
# Epoch 4/150
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 5/150
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 6/150
# 64/64 [==============================] - 3s 55ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 7/150
# 64/64 [==============================] - 4s 57ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 8/150
# 64/64 [==============================] - 4s 56ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 9/150
# 64/64 [==============================] - 3s 55ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 10/150
# 64/64 [==============================] - 3s 55ms/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 11/150
# 64/64 [==============================] - 3s 55ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 12/150
# 64/64 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 13/150
# 64/64 [==============================] - 4s 56ms/step - loss: 0.0012 - val_loss: 0.0080
# Epoch 14/150
# 64/64 [==============================] - 4s 55ms/step - loss: 0.0011 - val_loss: 0.0060
# Epoch 15/150
# 64/64 [==============================] - 4s 56ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 16/150
# 64/64 [==============================] - 4s 55ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 17/150
# 64/64 [==============================] - 4s 56ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 18/150
# 64/64 [==============================] - 4s 56ms/step - loss: 0.0011 - val_loss: 0.0048
# Epoch 19/150
# 64/64 [==============================] - 4s 56ms/step - loss: 9.1882e-04 - val_loss: 0.0038
# Epoch 20/150
# 64/64 [==============================] - 4s 56ms/step - loss: 9.0681e-04 - val_loss: 0.0026
# Epoch 21/150
# 64/64 [==============================] - 4s 56ms/step - loss: 8.9755e-04 - val_loss: 0.0020
# Epoch 22/150
# 64/64 [==============================] - 4s 56ms/step - loss: 8.6068e-04 - val_loss: 0.0040
# Epoch 23/150
# 64/64 [==============================] - 4s 56ms/step - loss: 8.8892e-04 - val_loss: 0.0035
# Epoch 24/150
# 64/64 [==============================] - 4s 57ms/step - loss: 8.0431e-04 - val_loss: 0.0026
# Epoch 25/150
# 64/64 [==============================] - 4s 56ms/step - loss: 7.9804e-04 - val_loss: 0.0018
# Epoch 26/150
# 64/64 [==============================] - 4s 56ms/step - loss: 8.0549e-04 - val_loss: 9.2391e-04
# Epoch 27/150
# 64/64 [==============================] - 4s 56ms/step - loss: 6.8665e-04 - val_loss: 9.6390e-04
# Epoch 28/150
# 64/64 [==============================] - 4s 56ms/step - loss: 6.7340e-04 - val_loss: 0.0016
# Epoch 29/150
# 64/64 [==============================] - 4s 56ms/step - loss: 7.3818e-04 - val_loss: 0.0010
# Epoch 30/150
# 64/64 [==============================] - 4s 56ms/step - loss: 6.7765e-04 - val_loss: 0.0010
# Epoch 31/150
# 64/64 [==============================] - 4s 56ms/step - loss: 6.3295e-04 - val_loss: 0.0013
# Epoch 32/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.8117e-04 - val_loss: 0.0010
# Epoch 33/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.2043e-04 - val_loss: 8.6079e-04
# Epoch 34/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.0779e-04 - val_loss: 7.4041e-04
# Epoch 35/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.3370e-04 - val_loss: 5.9069e-04
# Epoch 36/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.0899e-04 - val_loss: 8.3534e-04
# Epoch 37/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.8028e-04 - val_loss: 0.0018
# Epoch 38/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.5492e-04 - val_loss: 0.0013
# Epoch 39/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.7586e-04 - val_loss: 9.0206e-04
# Epoch 40/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.3981e-04 - val_loss: 6.5147e-04
# Epoch 41/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.8591e-04 - val_loss: 0.0012
# Epoch 42/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.5937e-04 - val_loss: 6.2921e-04
# Epoch 43/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.5865e-04 - val_loss: 5.6258e-04
# Epoch 44/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.0832e-04 - val_loss: 0.0015
# Epoch 45/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.1238e-04 - val_loss: 0.0044
# Epoch 46/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.1461e-04 - val_loss: 7.3287e-04
# Epoch 47/150
# 64/64 [==============================] - 4s 57ms/step - loss: 4.8884e-04 - val_loss: 8.0053e-04
# Epoch 48/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.2146e-04 - val_loss: 0.0015
# Epoch 49/150
# 64/64 [==============================] - 4s 57ms/step - loss: 4.9773e-04 - val_loss: 0.0012
# Epoch 50/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.7360e-04 - val_loss: 6.2585e-04
# Epoch 51/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.9033e-04 - val_loss: 7.4902e-04
# Epoch 52/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.3517e-04 - val_loss: 0.0012
# Epoch 53/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.8249e-04 - val_loss: 5.3541e-04
# Epoch 54/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.7162e-04 - val_loss: 9.3317e-04
# Epoch 55/150
# 64/64 [==============================] - 4s 57ms/step - loss: 4.9661e-04 - val_loss: 0.0013
# Epoch 56/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.7023e-04 - val_loss: 7.5550e-04
# Epoch 57/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.4205e-04 - val_loss: 8.9517e-04
# Epoch 58/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.5622e-04 - val_loss: 7.5180e-04
# Epoch 59/150
# 64/64 [==============================] - 4s 61ms/step - loss: 4.7168e-04 - val_loss: 8.1380e-04
# Epoch 60/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.3194e-04 - val_loss: 5.1624e-04
# Epoch 61/150
# 64/64 [==============================] - 4s 61ms/step - loss: 4.4097e-04 - val_loss: 7.7469e-04
# Epoch 62/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.4773e-04 - val_loss: 0.0014
# Epoch 63/150
# 64/64 [==============================] - 4s 56ms/step - loss: 4.0886e-04 - val_loss: 0.0011
# Epoch 64/150
# 64/64 [==============================] - 4s 56ms/step - loss: 4.5352e-04 - val_loss: 0.0011
# Epoch 65/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.1338e-04 - val_loss: 5.1894e-04
# Epoch 66/150
# 64/64 [==============================] - 4s 63ms/step - loss: 4.3530e-04 - val_loss: 0.0011
# Epoch 67/150
# 64/64 [==============================] - 4s 62ms/step - loss: 4.0550e-04 - val_loss: 5.2255e-04
# Epoch 68/150
# 64/64 [==============================] - 4s 62ms/step - loss: 4.1860e-04 - val_loss: 0.0019
# Epoch 69/150
# 64/64 [==============================] - 4s 60ms/step - loss: 4.0225e-04 - val_loss: 0.0024
# Epoch 70/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.4229e-04 - val_loss: 0.0029
# Epoch 71/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.8610e-04 - val_loss: 8.8927e-04
# Epoch 72/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.7875e-04 - val_loss: 0.0012
# Epoch 73/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.9768e-04 - val_loss: 7.0660e-04
# Epoch 74/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.8988e-04 - val_loss: 5.2538e-04
# Epoch 75/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.9899e-04 - val_loss: 8.2051e-04
# Epoch 76/150
# 64/64 [==============================] - 4s 62ms/step - loss: 4.1002e-04 - val_loss: 5.6064e-04
# Epoch 77/150
# 64/64 [==============================] - 4s 61ms/step - loss: 4.1523e-04 - val_loss: 7.1302e-04
# Epoch 78/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4721e-04 - val_loss: 0.0011
# Epoch 79/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.2590e-04 - val_loss: 0.0020
# Epoch 80/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.8807e-04 - val_loss: 5.1409e-04
# Epoch 81/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.6524e-04 - val_loss: 6.0382e-04
# Epoch 82/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.6727e-04 - val_loss: 0.0013
# Epoch 83/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.0378e-04 - val_loss: 0.0018
# Epoch 84/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.8600e-04 - val_loss: 0.0026
# Epoch 85/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.9147e-04 - val_loss: 0.0012
# Epoch 86/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.7284e-04 - val_loss: 6.2581e-04
# Epoch 87/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.5204e-04 - val_loss: 5.8303e-04
# Epoch 88/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.6283e-04 - val_loss: 6.1421e-04
# Epoch 89/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.5882e-04 - val_loss: 8.6987e-04
# Epoch 90/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.6324e-04 - val_loss: 0.0012
# Epoch 91/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.6846e-04 - val_loss: 5.3321e-04
# Epoch 92/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.6435e-04 - val_loss: 0.0011
# Epoch 93/150
# 64/64 [==============================] - 4s 62ms/step - loss: 3.6604e-04 - val_loss: 6.5122e-04
# Epoch 94/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.6040e-04 - val_loss: 0.0016
# Epoch 95/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.5594e-04 - val_loss: 0.0014
# Epoch 96/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.6287e-04 - val_loss: 0.0026
# Epoch 97/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.6891e-04 - val_loss: 0.0020
# Epoch 98/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.5069e-04 - val_loss: 5.1027e-04
# Epoch 99/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.7536e-04 - val_loss: 0.0014
# Epoch 100/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.7579e-04 - val_loss: 9.2724e-04
# Epoch 101/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4269e-04 - val_loss: 0.0029
# Epoch 102/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.3323e-04 - val_loss: 7.9295e-04
# Epoch 103/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.7697e-04 - val_loss: 0.0011
# Epoch 104/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.3653e-04 - val_loss: 0.0010
# Epoch 105/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4549e-04 - val_loss: 0.0014
# Epoch 106/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.4605e-04 - val_loss: 8.5794e-04
# Epoch 107/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4864e-04 - val_loss: 0.0011
# Epoch 108/150
# 64/64 [==============================] - 4s 68ms/step - loss: 3.3978e-04 - val_loss: 9.4792e-04
# Epoch 109/150
# 64/64 [==============================] - 4s 62ms/step - loss: 3.4749e-04 - val_loss: 7.3695e-04
# Epoch 110/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.3901e-04 - val_loss: 9.5992e-04
# Epoch 111/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4952e-04 - val_loss: 0.0015
# Epoch 112/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4236e-04 - val_loss: 0.0019
# Epoch 113/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4264e-04 - val_loss: 0.0024
# Epoch 114/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.3967e-04 - val_loss: 0.0011
# Epoch 115/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.3662e-04 - val_loss: 0.0019
# Epoch 116/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.2368e-04 - val_loss: 0.0015
# Epoch 117/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2757e-04 - val_loss: 0.0014
# Epoch 118/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.3233e-04 - val_loss: 0.0012
# Epoch 119/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.3605e-04 - val_loss: 6.5599e-04
# Epoch 120/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2756e-04 - val_loss: 8.7594e-04
# Epoch 121/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.5574e-04 - val_loss: 0.0012
# Epoch 122/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.2032e-04 - val_loss: 0.0017
# Epoch 123/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2143e-04 - val_loss: 0.0016
# Epoch 124/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.0885e-04 - val_loss: 0.0011
# Epoch 125/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.3155e-04 - val_loss: 0.0013
# Epoch 126/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.3086e-04 - val_loss: 0.0028
# Epoch 127/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.1068e-04 - val_loss: 0.0014
# Epoch 128/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.1193e-04 - val_loss: 0.0021
# Epoch 129/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.3352e-04 - val_loss: 8.9744e-04
# Epoch 130/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2690e-04 - val_loss: 0.0012
# Epoch 131/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.1625e-04 - val_loss: 9.8388e-04
# Epoch 132/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.1339e-04 - val_loss: 0.0016
# Epoch 133/150
# 64/64 [==============================] - 4s 56ms/step - loss: 3.0250e-04 - val_loss: 0.0029
# Epoch 134/150
# 64/64 [==============================] - 4s 58ms/step - loss: 3.4287e-04 - val_loss: 0.0014
# Epoch 135/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.0413e-04 - val_loss: 0.0011
# Epoch 136/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.0038e-04 - val_loss: 0.0015
# Epoch 137/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.3748e-04 - val_loss: 0.0015
# Epoch 138/150
# 64/64 [==============================] - 4s 62ms/step - loss: 2.9451e-04 - val_loss: 0.0010
# Epoch 139/150
# 64/64 [==============================] - 4s 57ms/step - loss: 3.2857e-04 - val_loss: 8.1906e-04
# Epoch 140/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4498e-04 - val_loss: 7.3940e-04
# Epoch 141/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.2365e-04 - val_loss: 0.0021
# Epoch 142/150
# 64/64 [==============================] - 4s 57ms/step - loss: 2.9759e-04 - val_loss: 0.0013
# Epoch 143/150
# 64/64 [==============================] - 4s 56ms/step - loss: 3.0272e-04 - val_loss: 0.0013
# Epoch 144/150
# 64/64 [==============================] - 4s 56ms/step - loss: 3.1792e-04 - val_loss: 0.0016
# Epoch 145/150
# 64/64 [==============================] - 4s 56ms/step - loss: 2.9076e-04 - val_loss: 0.0011
# Epoch 146/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.0511e-04 - val_loss: 0.0021
# Epoch 147/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.2656e-04 - val_loss: 0.0023
# Epoch 148/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.1590e-04 - val_loss: 0.0024
# Epoch 149/150
# 64/64 [==============================] - 4s 67ms/step - loss: 3.0617e-04 - val_loss: 0.0013
# Epoch 150/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.2558e-04 - val_loss: 0.0024

# %% [markdown]
# # Step 11: Model Evaluation
# __Next, we evaluate our time series forecast using MAPE (Mean Absolute Percentage Error) metric:__

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0017
# 9/9 [==============================] - 1s 17ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0016767276683822274
# Test MAPE: 0.04598779094658827
# Test Accuracy: 0.9540122090534118

# %% [markdown]
# # Step 12: Visualizing Results

# %% [markdown]
# __Returning the actual and predicted Price values to their primary scale:__

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %% [markdown]
# __Investigating the closeness of the prices predicted by the model to the real prices:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'white'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# ____
# # Conclusion:
# ### As can be seen, the price predicted by the LSTM model follows the actual prices greatly! The value of Loss and Accuracy (1-MAPE) obtained on the test data also confirm the great performance of the model:
#
# ## 🏆 Loss: 0.001
# ## 🏆 Accuracy: 96%

# %%
import numpy as np
import matplotlib.pyplot as plt

error = y_test_pred - y_test_true  

 
plt.figure(figsize=(10, 6))
plt.plot(df['Date'].iloc[-test_size:], error, color='purple', lw=2)
plt.title('Prediction Error Plot', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Prediction Error', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45, ha='right')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df['Date'].iloc[-test_size:], error, color='red', label='Residuals')
plt.axhline(y=0, color='black', linestyle='--', lw=2)
plt.title('Residual Plot', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()


MAE = np.mean(np.abs(error))
print(f'Mean Absolute Error (MAE): {MAE:.4f}')


MSE = np.mean(error**2)
RMSE = np.sqrt(MSE)
print(f'Mean Squared Error (MSE): {MSE:.4f}')
print(f'Root Mean Squared Error (RMSE): {RMSE:.4f}')


plt.figure(figsize=(10, 6))
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2, label='Actual Test Data')
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2, label='Predicted Test Data')
plt.title('Actual vs Predicted vs Error', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()
# Out:
# Mean Absolute Error (MAE): 33.8225
# Mean Squared Error (MSE): 1706.3695
# Root Mean Squared Error (RMSE): 41.3082

# %%
# import matplotlib.pyplot as plt
# import matplotlib.dates as mdates

# plt.figure(figsize=(15, 6), dpi=150)
# plt.rcParams['axes.facecolor'] = 'lightgray'  
# plt.rc('axes', edgecolor='black')


# plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2, linestyle='-', label='Training Data')


# plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2, linestyle='-', label='Actual Test Data')


# plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2, linestyle='--', label='Predicted Test Data')


# plt.title('Model Performance on Gold Price Prediction', fontsize=15, weight='bold')
# plt.xlabel('Date', fontsize=12)
# plt.ylabel('Price', fontsize=12)


# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))  # هر ۵ روز یک تاریخ نمایش داده شود
# plt.xticks(rotation=45, ha='right')


# plt.legend(loc='upper left', prop={'size': 12}, fancybox=True, facecolor='white', framealpha=0.7)


# plt.grid(color='white', linestyle='--', linewidth=0.5)


# plt.tight_layout() 
# plt.show()
